# %% [markdown]
# # Frame Objects
#
# > The C structure of the objects used to describe frame objects.
# >
# > There are no public members in this structure.
# >
# > 3.11 The members of this structure were removed from the public C API.
# > Refer to the `What's New entry <pyframeobject-3.11-hiding>` for
# > details.
#
# The :c`PyEval_GetFrame` and :c`PyThreadState_GetFrame` functions can be
# used to get a frame object.
#
# See also `Reflection <reflection>`.
#
# > Get the *frame* next outer frame.
# >
# > Return a `strong reference`, or `NULL` if *frame* has no outer frame.
# >
# > 3.9
#
# > Get the *frame*'s `f_builtins` attribute.
# >
# > Return a `strong reference`. The result cannot be `NULL`.
# >
# > 3.11
#
# > Get the *frame* code.
# >
# > Return a `strong reference`.
# >
# > The result (frame code) cannot be `NULL`.
# >
# > 3.9
#
# > Get the generator, coroutine, or async generator that owns this frame,
# > or `NULL` if this frame is not owned by a generator. Does not raise an
# > exception, even if the return value is `NULL`.
# >
# > Return a `strong reference`, or `NULL`.
# >
# > 3.11
#
# > Get the *frame*'s `f_globals` attribute.
# >
# > Return a `strong reference`. The result cannot be `NULL`.
# >
# > 3.11
#
# > Get the *frame*'s `f_lasti` attribute.
# >
# > Returns -1 if `frame.f_lasti` is `None`.
# >
# > 3.11
#
# > Get the *frame*'s `f_locals` attribute (`dict`).
# >
# > Return a `strong reference`.
# >
# > 3.11
#
# > Return the line number that *frame* is currently executing.
